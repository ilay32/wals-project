# %% [markdown]
# # All Stars
#
# I have nothing to say about this. I don't really understand what it adds to the one here:
# https://github.com/ilay32/wals-project/blob/master/case-gender.ipynb In [9]

# %%
from locator import *
from phonstats import agstats
# %matplotlib inline
g = ColGroup(['30A','31A','32A','49A','50A','51A'])

# %%
print(g.gen_separation(2),g.gen_separation(4))
# Out:
# 0.773627128059 0.26866132256

# %%
g.plot_multifam()
# Out:
# /usr/local/lib/python3.5/dist-packages/sklearn/metrics/cluster/unsupervised.py:204: RuntimeWarning: invalid value encountered in true_divide
#   sil_samples /= np.maximum(intra_clust_dists, inter_clust_dists)

# %% [markdown]
# ## Silhouettes by Single Feature:

# %%
g.raw_silhouettes.filter(items=[(c,c) for c in g.cols],axis=0)
# Out:
#          Austronesian                                           Indo-European  \
#         Indo-European Niger-Congo Afro-Asiatic Trans-New Guinea   Niger-Congo
# 30A 30A      0.598765       0.568            1              NaN      0.222328
# 31A 31A      0.783951       0.664            1              NaN      0.604878
# 32A 32A      0.722222       0.568            1              NaN     0.0369927
# 49A 49A      0.493827        0.16     0.538961         0.492063      0.347911
# 50A 50A       0.43739  -0.0702098     0.335065         0.380778      0.472383
#
#                                        Niger-Congo                   \
#         Afro-Asiatic Trans-New Guinea Afro-Asiatic Trans-New Guinea
# 30A 30A     0.269841         0.458333     0.621053              0.4
# 31A 31A    -0.134921         0.708333     0.747368         0.533333
# 32A 32A   -0.0873016            0.625     0.147368              0.4
# 49A 49A  -0.00348263        0.0681555     0.338055         0.262626
# ...

# %% [markdown]
# ## By Single Features and Feature Pairs

# %%
g.raw_silhouettes
# Out:
#          Austronesian                                           Indo-European  \
#         Indo-European Niger-Congo Afro-Asiatic Trans-New Guinea   Niger-Congo
# 30A 30A      0.598765       0.568            1              NaN      0.222328
#     31A      0.691358       0.616            1              NaN      0.426337
#     32A      0.660494       0.568            1              NaN      0.171121
#     49A      0.542815        0.53     0.808442         0.492063      0.280887
#     50A      0.515743    0.441038     0.720525         0.380778      0.353337
#     51A       0.57301    0.454802     0.761879         0.360544      0.325554
# 31A 31A      0.783951       0.664            1              NaN      0.604878
#     32A      0.753086       0.616            1              NaN      0.420673
#     49A      0.638482       0.622     0.808442         0.492063      0.478158
#     50A      0.611978    0.522038     0.720525         0.380778         0.541
# ...

# %%
g.plot_silhouettes('genetic',2,True)
