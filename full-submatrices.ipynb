# %%
from locator import locate_all_columns
import pandas as pd
wals = pd.read_csv('language.csv')
coverage = wals.ix[:,10:]
coverage = coverage.replace(to_replace=".+",regex=True,value=1)
coverage = coverage.replace(to_replace='',value=0)
thou = locate_all_columns(coverage,1000)
len(thou)
# Out:
# 9

# %%
thou[8]
# Out:
# [['143A Order of Negative Morpheme and Verb',
#   '143E Preverbal Negative Morphemes',
#   '143F Postverbal Negative Morphemes',
#   '143G Minor morphological means of signaling negation',
#   '81A Order of Subject, Object and Verb',
#   '82A Order of Subject and Verb',
#   '83A Order of Object and Verb',
#   '87A Order of Adjective and Noun',
#   '97A Relationship between the Order of Object and Verb and the Order of Adjective and Noun'],
#  ['143A Order of Negative Morpheme and Verb',
#   '143E Preverbal Negative Morphemes',
#   '143F Postverbal Negative Morphemes',
#   '143G Minor morphological means of signaling negation',
#   '144A Position of Negative Word With Respect to Subject, Object, and Verb',
#   '82A Order of Subject and Verb',
#   '83A Order of Object and Verb',
#   '87A Order of Adjective and Noun',
#   '97A Relationship between the Order of Object and Verb and the Order of Adjective and Noun']]

# %%
thou[7]
# Out:
# [['143A Order of Negative Morpheme and Verb',
#   '143E Preverbal Negative Morphemes',
#   '143F Postverbal Negative Morphemes',
#   '81A Order of Subject, Object and Verb',
#   '82A Order of Subject and Verb',
#   '83A Order of Object and Verb',
#   '87A Order of Adjective and Noun',
#   '97A Relationship between the Order of Object and Verb and the Order of Adjective and Noun'],
#  ['143E Preverbal Negative Morphemes',
#   '143F Postverbal Negative Morphemes',
#   '143G Minor morphological means of signaling negation',
#   '81A Order of Subject, Object and Verb',
#   '82A Order of Subject and Verb',
#   '83A Order of Object and Verb',
#   '87A Order of Adjective and Noun',
#   '97A Relationship between the Order of Object and Verb and the Order of Adjective and Noun'],
#  ['143A Order of Negative Morpheme and Verb',
#   '143F Postverbal Negative Morphemes',
#   '143G Minor morphological means of signaling negation',
#   '81A Order of Subject, Object and Verb',
#   '82A Order of Subject and Verb',
#   '83A Order of Object and Verb',
#   '87A Order of Adjective and Noun',
#   '97A Relationship between the Order of Object and Verb and the Order of Adjective and Noun'],
#  ['143A Order of Negative Morpheme and Verb',
#   '143E Preverbal Negative Morphemes',
#   '143G Minor morphological means of signaling negation',
#   '81A Order of Subject, Object and Verb',
#   '82A Order of Subject and Verb',
#   '83A Order of Object and Verb',
#   '87A Order of Adjective and Noun',
#   '97A Relationship between the Order of Object and Verb and the Order of Adjective and Noun'],
#  ['143A Order of Negative Morpheme and Verb',
#   '143E Preverbal Negative Morphemes',
#   '143F Postverbal Negative Morphemes',
#   '143G Minor morphological means of signaling negation',
#   '81A Order of Subject, Object and Verb',
#   '82A Order of Subject and Verb',
#   '83A Order of Object and Verb',
#   '87A Order of Adjective and Noun'],
#  ['143A Order of Negative Morpheme and Verb',
#   '143E Preverbal Negative Morphemes',
#   '143F Postverbal Negative Morphemes',
#   '143G Minor morphological means of signaling negation',
#   '81A Order of Subject, Object and Verb',
#   '82A Order of Subject and Verb',
#   '83A Order of Object and Verb',
#   '97A Relationship between the Order of Object and Verb and the Order of Adjective and Noun'],
#  ['112A Negative Morphemes',
#   '143A Order of Negative Morpheme and Verb',
#   '143E Preverbal Negative Morphemes',
#   '143F Postverbal Negative Morphemes',
#   '143G Minor morphological means of signaling negation',
#   '81A Order of Subject, Object and Verb',
#   '82A Order of Subject and Verb',
#   '83A Order of Object and Verb'],
#  ['143A Order of Negative Morpheme and Verb',
#   '143E Preverbal Negative Morphemes',
#   '143F Postverbal Negative Morphemes',
#   '143G Minor morphological means of signaling negation',
#   '144A Position of Negative Word With Respect to Subject, Object, and Verb',
#   '81A Order of Subject, Object and Verb',
#   '82A Order of Subject and Verb',
#   '83A Order of Object and Verb'],
#  ['143A Order of Negative Morpheme and Verb',
#   '143E Preverbal Negative Morphemes',
#   '143F Postverbal Negative Morphemes',
#   '143G Minor morphological means of signaling negation',
#   '81A Order of Subject, Object and Verb',
#   '82A Order of Subject and Verb',
#   '87A Order of Adjective and Noun',
#   '97A Relationship between the Order of Object and Verb and the Order of Adjective and Noun'],
#  ['143A Order of Negative Morpheme and Verb',
#   '143E Preverbal Negative Morphemes',
#   '143F Postverbal Negative Morphemes',
#   '143G Minor morphological means of signaling negation',
#   '81A Order of Subject, Object and Verb',
#   '83A Order of Object and Verb',
#   '87A Order of Adjective and Noun',
#   '97A Relationship between the Order of Object and Verb and the Order of Adjective and Noun'],
#  ['143A Order of Negative Morpheme and Verb',
#   '143E Preverbal Negative Morphemes',
#   '143F Postverbal Negative Morphemes',
#   '144A Position of Negative Word With Respect to Subject, Object, and Verb',
#   '82A Order of Subject and Verb',
#   '83A Order of Object and Verb',
#   '87A Order of Adjective and Noun',
#   '97A Relationship between the Order of Object and Verb and the Order of Adjective and Noun'],
#  ['143E Preverbal Negative Morphemes',
#   '143F Postverbal Negative Morphemes',
#   '143G Minor morphological means of signaling negation',
#   '144A Position of Negative Word With Respect to Subject, Object, and Verb',
#   '82A Order of Subject and Verb',
#   '83A Order of Object and Verb',
#   '87A Order of Adjective and Noun',
#   '97A Relationship between the Order of Object and Verb and the Order of Adjective and Noun'],
#  ['143A Order of Negative Morpheme and Verb',
#   '143F Postverbal Negative Morphemes',
#   '143G Minor morphological means of signaling negation',
#   '144A Position of Negative Word With Respect to Subject, Object, and Verb',
#   '82A Order of Subject and Verb',
#   '83A Order of Object and Verb',
#   '87A Order of Adjective and Noun',
#   '97A Relationship between the Order of Object and Verb and the Order of Adjective and Noun'],
#  ['143A Order of Negative Morpheme and Verb',
#   '143E Preverbal Negative Morphemes',
#   '143F Postverbal Negative Morphemes',
#   '143G Minor morphological means of signaling negation',
#   '82A Order of Subject and Verb',
#   '83A Order of Object and Verb',
#   '87A Order of Adjective and Noun',
#   '97A Relationship between the Order of Object and Verb and the Order of Adjective and Noun'],
#  ['143A Order of Negative Morpheme and Verb',
#   '143E Preverbal Negative Morphemes',
#   '143G Minor morphological means of signaling negation',
#   '144A Position of Negative Word With Respect to Subject, Object, and Verb',
#   '82A Order of Subject and Verb',
#   '83A Order of Object and Verb',
#   '87A Order of Adjective and Noun',
#   '97A Relationship between the Order of Object and Verb and the Order of Adjective and Noun'],
#  ['143A Order of Negative Morpheme and Verb',
#   '143E Preverbal Negative Morphemes',
#   '143F Postverbal Negative Morphemes',
#   '143G Minor morphological means of signaling negation',
#   '144A Position of Negative Word With Respect to Subject, Object, and Verb',
#   '82A Order of Subject and Verb',
#   '83A Order of Object and Verb',
#   '87A Order of Adjective and Noun'],
#  ['143A Order of Negative Morpheme and Verb',
#   '143E Preverbal Negative Morphemes',
#   '143F Postverbal Negative Morphemes',
#   '143G Minor morphological means of signaling negation',
#   '144A Position of Negative Word With Respect to Subject, Object, and Verb',
#   '82A Order of Subject and Verb',
#   '83A Order of Object and Verb',
#   '97A Relationship between the Order of Object and Verb and the Order of Adjective and Noun'],
#  ['112A Negative Morphemes',
#   '143A Order of Negative Morpheme and Verb',
#   '143E Preverbal Negative Morphemes',
#   '143F Postverbal Negative Morphemes',
#   '143G Minor morphological means of signaling negation',
#   '144A Position of Negative Word With Respect to Subject, Object, and Verb',
#   '82A Order of Subject and Verb',
#   '83A Order of Object and Verb'],
#  ['143A Order of Negative Morpheme and Verb',
#   '143E Preverbal Negative Morphemes',
#   '143F Postverbal Negative Morphemes',
#   '143G Minor morphological means of signaling negation',
#   '144A Position of Negative Word With Respect to Subject, Object, and Verb',
#   '82A Order of Subject and Verb',
#   '87A Order of Adjective and Noun',
#   '97A Relationship between the Order of Object and Verb and the Order of Adjective and Noun'],
#  ['143A Order of Negative Morpheme and Verb',
#   '143E Preverbal Negative Morphemes',
#   '143F Postverbal Negative Morphemes',
#   '143G Minor morphological means of signaling negation',
#   '144A Position of Negative Word With Respect to Subject, Object, and Verb',
#   '83A Order of Object and Verb',
#   '87A Order of Adjective and Noun',
#   '97A Relationship between the Order of Object and Verb and the Order of Adjective and Noun']]

# %%
wals[thou[7][5]].describe()
# Out:
#        143A Order of Negative Morpheme and Verb  \
# count                                      1324
# unique                                       17
# top                                      1 NegV
# freq                                        524
#
#        143E Preverbal Negative Morphemes 143F Postverbal Negative Morphemes  \
# count                               1324                               1324
# unique                                 4                                  4
# top                               1 NegV                             4 None
# freq                                 681                                711
#
#        143G Minor morphological means of signaling negation  \
# count                                                1324
# unique                                                  4
# top                                                4 None
# freq                                                 1314
#
#        81A Order of Subject, Object and Verb 82A Order of Subject and Verb  \
# count                                   1377                          1497
# unique                                     7                             3
# top                                    1 SOV                          1 SV
# freq                                     565                          1193
#
#        83A Order of Object and Verb  \
# count                          1519
# unique                            3
# top                            1 OV
# freq                            713
#
#        97A Relationship between the Order of Object and Verb and the Order of Adjective and Noun
# count                                                1316
# unique                                                  5
# top                                         4 VO and NAdj
# freq                                                  456
